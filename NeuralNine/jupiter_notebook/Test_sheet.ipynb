# %%
sth = 'papaja ' * 5

print(f'Something wonderfull: {sth}')
# Out:
# Something wonderfull: papaja papaja papaja papaja papaja

# %%
sth[0:5]
# Out:
# 'papaj'

# %%
import pandas_datareader as web

# %%
df = web.DataReader('TSLA', 'yahoo')

# %%
df.head(5)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-06-13  75.199997  73.321999  73.524002  75.190002  59039500.0  75.190002
# 2017-06-14  76.849998  75.262001  76.218002  76.132004  64092000.0  76.132004
# 2017-06-15  75.092003  73.297997  74.500000  75.068001  52132500.0  75.068001
# 2017-06-16  75.601997  74.019997  75.596001  74.279999  33655000.0  74.279999
# 2017-06-19  75.339996  73.559998  75.000000  73.959999  32746500.0  73.959999

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# %matplotlib inline
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# %matplotlib tk
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # My
# ## FCK
# ### Restaurant
#
# And *I* like **it**
#
# * i
# * duno
# * for
# * sure
#
# 1. i
# 2. like
# 3. trains

# %% [markdown]
# $$\Phi^n + \Pi^{n-1} - 1n$$

# %%
# %%latex
# \begin{align}
# \pi^n + \rho^{n-1} - 1n
# \end{align}
# Out:
# \begin{align}
# \pi^n + \rho^{n-1} - 1n
# \end{align}

# %%
# %timeit pass
# Out:
# 4.6 ns ± 0.0181 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
def timefiller(x):
    res = 0
    for i in range (x):
        res += sum({x^2, x^3, x^5})
    return res

# %%
# %%timeit 
timefiller(2)
# Out:
# 551 ns ± 10.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit 
timefiller(2)
timefiller(2)
# Out:
# 1.08 µs ± 7.47 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %pwd
# Out:
# 'H:\\PycharmProjects\\Scrypts\\Poligon\\NeuralNine\\jupiter_notebook'

# %%
# %%writefile cell.py
def example_sth(sth):
    print(sth + ' ' + sth)
    
example_sth(papaja)
# Out:
# Writing cell.py

# %%
# %history
# Out:
# import pandas_datareader as web
# df = web.DataReader('TSLA', 'yahoo')
# %matplotlib qt5
# df.plot()
# %matplotlib inline
# df.plot()
# # My
# # My
# # My
# ## FCK
# ### Restaurant
#
# * i
# * duno
# * for
# * sure
#
# 1. i
# 2. like
# 3. trains
# # My
# ## *FCK*
# ### **Restaurant**
#
# * i
# * duno
# * fo
# * sure
#
# 1. i
# 2. like
# 3. trains
# # My
# ## *FCK*
# ### **Restaurant**
#
# * i
# * duno
# * fo
# * sure
#
# 1. i
# 2. like
# 3. trains
# %%latex
# \begine{align}
# \Pi^n + \Ro^{n-1} - 1n$$
# \end{align}
# %%latex
# \begine{align}
# \Pi^n + \Ro^{n-1} - 1n
# \end{align}
# %%latex
# \begine{align}
# \Pi^n + \Phi^{n-1} - 1n
# \end{align}
# %%latex
# \begin{align}
# \Pi^n + \Ro^{n-1} - 1n
# \end{align}
# %%latex
# \begin{align}
# \Pi^n + \Rho^{n-1} - 1n
# \end{align}
# %%latex
# \begin{align}
# \Pi^n + \rho^{n-1} - 1n
# \end{align}
# %%latex
# \begin{align}
# \pi^n + \rho^{n-1} - 1n
# \end{align}
# %timeit pass
# def timefiller(x):
#     res = 0
#     for i in range (x):
# ...

# %%
example_list = [12, 22, 11, 8]
# %store example_list
# Out:
# Stored 'example_list' (list)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
# !pip install whatever
